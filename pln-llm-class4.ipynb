# %% [markdown]
# O que é PLN?
#
# - Entendimento de Linguagem Natural (NLU)
# - Geração de Linguagem Natural (NLG)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Aplicações de PLN (NLU)
# - AM em texto: classificação, clusterização, regressão
# - Recomendação de documentos
# - Análise de sentimentos
# - Sumarização de textos
# - [...]
#
# Aplicações de PLN (NLG)
# - Criação de imagens
# - Sumarização de texto
# - Chatbots
# -

# %% [markdown]
# Como o NLP evoluiu
# - 1950-1980: métodos linguísticos baseados em regras
# - 1980-2010: métodos estatísticos (AM clássica)
# - 2010-dias atuais: Deep learning (conseguiu-se criar hardware e software para processar redes neurais profundas: GPUs, TensorFlow, PyTorch)

# %% [markdown]
# Expressões regulares: com Quemuel
